# %%
import os, math, time, cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [12,9]
from matplotlib.pyplot import imshow

from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import fbeta_score

from utils.data_utils import *

# %%
df_train = pd.read_csv('inputs/train_v2.csv')
labels, label_map, inv_label_map = get_labels()

# %%
def show_examples(data, num, cols = 4, zoom=2):
    rows = int(math.ceil(num/cols))
    _, ax = plt.subplots(rows, cols, figsize=(cols*zoom, rows*zoom))
    for i in range(num):
        if len(ax.shape) > 1:
            ax[i // cols, i % cols].imshow((255*data[i]).astype(np.uint8))
        else:
            ax[i].imshow((255*data[i]).astype(np.uint8))

# %%
start = time.time()
X, Y = load_jpg_data(df_train, 'inputs/train-jpg', label_map, img_size=256, subset_size=1000)
end = time.time()
print ("Time: %.3f[s]" % (end - start))
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 820.59it/s]
# Creating numpy array for data...
# Time: 4.666[s]

# %%
start = time.time()
X, Y = load_data(df_train, 'inputs/train-jpg', label_map, img_size=128)
end = time.time()
print ("Time: %.3f[s]" % (end - start))
# Out:
# 100%|██████████| 40479/40479 [00:44<00:00, 907.11it/s]
# Creating numpy array for data...
# Time: 44.646[s]

# %%
show_examples(X, 4, cols=2, zoom=4)
